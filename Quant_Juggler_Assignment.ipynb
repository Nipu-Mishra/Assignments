# %% [markdown]
# <a href="https://colab.research.google.com/github/Nipu-Mishra/Assignments/blob/main/Quant_Juggler_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from datetime import datetime

# %%
# Load the data
data = pd.read_csv('/content/Clean_Files000.csv')

# %%
# Load the data into the dataframe
df = pd.DataFrame(data)
df
# Out:
#                        Ticker      Date             Time    Open    High  \
# 0     BANKNIFTY02JUN1617500PE  6/1/2016  0 days 09:15:59   50.05   65.95
# 1     BANKNIFTY02JUN1617600PE  6/1/2016  0 days 09:15:59   77.35  105.00
# 2     BANKNIFTY02JUN1617500CE  6/1/2016  0 days 09:15:59  150.05  166.50
# 3     BANKNIFTY02JUN1617400PE  6/1/2016  0 days 09:15:59   28.95   34.80
# 4     BANKNIFTY02JUN1617900CE  6/1/2016  0 days 09:15:59   21.45   21.50
# ...                       ...       ...              ...     ...     ...
# 6375  BANKNIFTY02JUN1617100PE  6/1/2016  0 days 15:30:59    5.00    5.00
# 6376  BANKNIFTY02JUN1617800CE  6/1/2016  0 days 15:30:59    3.95    3.95
# 6377  BANKNIFTY02JUN1617400PE  6/1/2016  0 days 15:30:59   48.05   48.05
# 6378  BANKNIFTY02JUN1617700CE  6/1/2016  0 days 15:30:59    8.25    8.25
# 6379  BANKNIFTY02JUN1617500CE  6/1/2016  0 days 15:30:59   50.00   50.00
#
#          Low   Close  Volume  Open Interest      index expiry_date  Strike  \
# ...

# %% [markdown]
# # 1. Filter price between 200 and 300 from close column.

# %%
# 1. Filter price between 200 and 300 from close column.
df[(df['Close'] > 200 ) & (df['Close'] < 300)]
# Out:
#                        Ticker      Date             Time    Open    High  \
# 9     BANKNIFTY02JUN1617300CE  6/1/2016  0 days 09:15:59  299.00  299.00
# 29    BANKNIFTY02JUN1617300CE  6/1/2016  0 days 09:16:59  299.00  299.00
# 47    BANKNIFTY02JUN1617400CE  6/1/2016  0 days 09:17:59  200.00  202.25
# 63    BANKNIFTY02JUN1617300CE  6/1/2016  0 days 09:18:59  282.30  282.30
# 86    BANKNIFTY02JUN1617300CE  6/1/2016  0 days 09:19:59  265.10  277.85
# ...                       ...       ...              ...     ...     ...
# 6310  BANKNIFTY02JUN1617700PE  6/1/2016  0 days 15:27:59  269.15  269.15
# 6321  BANKNIFTY02JUN1617200CE  6/1/2016  0 days 15:27:59  235.95  250.05
# 6343  BANKNIFTY02JUN1617700PE  6/1/2016  0 days 15:28:59  249.35  252.00
# 6351  BANKNIFTY02JUN1617700PE  6/1/2016  0 days 15:29:59  238.85  254.75
# 6360  BANKNIFTY02JUN1617200CE  6/1/2016  0 days 15:29:59  250.00  250.00
#
#          Low   Close  Volume  Open Interest      index expiry_date  Strike  \
# ...

# %% [markdown]
# # 2. Filter time with 10:00:59.

# %%
# Check the data types
df.dtypes
# Out:
# Ticker            object
# Date              object
# Time              object
# Open             float64
# High             float64
# Low              float64
# Close            float64
# Volume             int64
# Open Interest      int64
# index             object
# expiry_date       object
# Strike             int64
# OptionType        object
# dte                int64
# dtype: object

# %%
# Convert the object into the integer
df['Time'] = df['Time'].str.replace('0 days','')
df['Time'] = df['Time'].str.replace(':','')
df['Time'] = df['Time'].astype(int)

# %%
# Check the dtype of the time
df['Time']
# Out:
# 0        91559
# 1        91559
# 2        91559
# 3        91559
# 4        91559
#          ...
# 6375    153059
# 6376    153059
# 6377    153059
# 6378    153059
# 6379    153059
# Name: Time, Length: 6380, dtype: int64

# %%
df[(df['Time'] == 100059)]
# Out:
#                       Ticker      Date    Time    Open    High     Low  \
# 785  BANKNIFTY02JUN1617900CE  6/1/2016  100059   12.60   13.50   12.60
# 786  BANKNIFTY02JUN1617400PE  6/1/2016  100059   27.80   27.80   25.95
# 787  BANKNIFTY02JUN1617100PE  6/1/2016  100059    3.30    3.35    3.15
# 788  BANKNIFTY02JUN1618000CE  6/1/2016  100059    6.10    6.70    6.05
# 789  BANKNIFTY02JUN1618200CE  6/1/2016  100059    0.95    0.95    0.95
# 790  BANKNIFTY02JUN1617300PE  6/1/2016  100059   12.95   13.00   12.35
# 791  BANKNIFTY02JUN1617200PE  6/1/2016  100059    6.25    6.60    6.20
# 792  BANKNIFTY02JUN1617600PE  6/1/2016  100059   96.20   96.55   90.00
# 793  BANKNIFTY02JUN1617000PE  6/1/2016  100059    2.00    2.05    1.90
# 794  BANKNIFTY02JUN1617400CE  6/1/2016  100059  211.05  232.80  211.05
# 795  BANKNIFTY02JUN1616900PE  6/1/2016  100059    1.00    1.00    1.00
# 796  BANKNIFTY02JUN1617500PE  6/1/2016  100059   55.00   55.25   51.20
# ...

# %% [markdown]
# # 3 **Filter** Ticker with BANKNIFTY

# %%
# 3 Filter Ticker with BANKNIFTY
df[df['Ticker'].str.contains('BANKNIFTY')]
# Out:
#                        Ticker      Date    Time    Open    High     Low  \
# 0     BANKNIFTY02JUN1617500PE  6/1/2016   91559   50.05   65.95   42.55
# 1     BANKNIFTY02JUN1617600PE  6/1/2016   91559   77.35  105.00   75.65
# 2     BANKNIFTY02JUN1617500CE  6/1/2016   91559  150.05  166.50  141.05
# 3     BANKNIFTY02JUN1617400PE  6/1/2016   91559   28.95   34.80   24.10
# 4     BANKNIFTY02JUN1617900CE  6/1/2016   91559   21.45   21.50   14.40
# ...                       ...       ...     ...     ...     ...     ...
# 6375  BANKNIFTY02JUN1617100PE  6/1/2016  153059    5.00    5.00    5.00
# 6376  BANKNIFTY02JUN1617800CE  6/1/2016  153059    3.95    3.95    3.95
# 6377  BANKNIFTY02JUN1617400PE  6/1/2016  153059   48.05   48.05   48.05
# 6378  BANKNIFTY02JUN1617700CE  6/1/2016  153059    8.25    8.25    8.25
# 6379  BANKNIFTY02JUN1617500CE  6/1/2016  153059   50.00   50.00   50.00
#
#        Close  Volume  Open Interest      index expiry_date  Strike OptionType  \
# ...
